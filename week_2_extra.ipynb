# %% [markdown]
# # Extra problem 1

# %% [markdown]
# ![Screenshot 2025-06-08 at 12.18.58.png](data:image/png;base64,...)

# %%
print(1+2/3 + 3+4/5 - 7)
# Out:
# -1.533333333333334

# %% [markdown]
# # Extra problem 2

# %% [markdown]
# x= 0.6666.... repeat
#
# to get the fraction:
#
# 10x = 6.666....
#
# 10x - x = 6.666...- 0.6666...
#
# 9x = 6
#
# x = 2/3 ----this is the fraction, but only works for single digit that repeats is a factor of 9.
